# %% [markdown]
# # Submission with Even faster submission
#
# [Thanks to this notebook for the even faster submission](https://www.kaggle.com/samusram/even-faster-hpa-cell-segmentation)
#
# So for submission this is how it is going to look:
#
#
# <code>ID Width Height Predicition_String</code>
#
# Where Prediction string is:
#
# <code>0_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 1_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 2_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 3_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 4_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 5_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 6_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 7_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 8_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 9_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 10_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 11_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 12_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 13_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 14_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 15_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 16_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 17_class cell_0_class_prob cell_0_rle_binary_mask_encoded
# 18_class cell_0_class_prob cell_0_rle_binary_mask_encoded</code>
#
# <code>0_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 1_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 2_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 3_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 4_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 5_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 6_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 7_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 8_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 9_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 10_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 11_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 12_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 13_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 14_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 15_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 16_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 17_class cell_1_class_prob cell_1_rle_binary_mask_encoded
# 18_class cell_1_class_prob cell_1_rle_binary_mask_encoded</code>
#
#
# ...
#
# <code>0_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 1_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 2_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 3_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 4_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 5_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 6_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 7_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 8_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 9_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 10_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 11_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 12_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 13_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 14_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 15_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 16_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 17_class cell_n_class_prob cell_n_rle_binary_mask_encoded
# 18_class cell_n_class_prob cell_n_rle_binary_mask_encoded</code>
#
#
#
# So as you can see, It is going to be pretty long.
#
# The sample_submission.csv contains all the test folder ID's so all we need to do is predict on all of those images in the above format.

# %%
tez_path = '../input/dyno-pytorch'
import sys
sys.path.append(tez_path)

# %%
# For pixel normalisation
MEAN_CHANNEL_VALUES = (0.07843, 0.05381, 0.06853)  
CHANNEL_STD_DEV = ( 0.12131, 0.080155, 0.142555)


# Path to weights
MODEL_PATH = '../input/models2/early_split_0.bin'
RESNET_PATH = '../input/models2/resnet18.pth'

# %%
# !pip install -q "../input/pycocotools/pycocotools-2.0-cp37-cp37m-linux_x86_64.whl"
# !pip install -q "../input/hpapytorchzoozip/pytorch_zoo-master"
# !pip install -q "../input/hpacellsegmentatorraman/HPA-Cell-Segmentation"

# %%
# imports
import pandas as pd 
import base64
import numpy as np
from pycocotools import _mask as coco_mask
from typing import List, Tuple
import zlib
import glob
import imageio
import matplotlib.pyplot as plt
import random

# model
import torch
from torch import nn
from torchvision.models import resnet18
import tez
import albumentations as A
import numpy as np
from skimage.transform import resize

# HPA
import os
import imageio
from hpacellseg.cellsegmentator import CellSegmentator
from hpacellseg.utils import label_cell

# %%
import hpacellseg.cellsegmentator as cellsegmentator
from hpacellseg.utils import label_cell, label_nuclei

NUC_MODEL = '../input/hpacellsegmentatormodelweights/dpn_unet_nuclei_v1.pth'
CELL_MODEL = '../input/hpacellsegmentatormodelweights/dpn_unet_cell_3ch_v1.pth'

# no padding or scaling :/
segmentator = cellsegmentator.CellSegmentator(
    NUC_MODEL,
    CELL_MODEL,
    device='cuda',
    multi_channel_model=True
)
# Out:
# please compile abn
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'pytorch_zoo.unet.DPNUnet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.upsampling.Upsample' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %% [markdown]
# # assigning bio style variables to images
#
# <code>mt = red_images # microtubules
# er = yellow_images # endoplasmic reticulum
# nu = blue_images # nucleus
# pr = green_images # [proteins]
# images = [mt, er, nu]</code>

# %% [markdown]
# ## Model

# %%
class ResNet18(tez.Model):
    '''Model class to facilitate transfer learning 
    from a resnet-18 model
    '''
    NUM_CLASSES = 19
    DROPOUT_RATE = 0.1
    
    def __init__(self, resnet, train_df=None, valid_df=None, batch_size=16, train_aug=None, valid_aug=None, pretrained=True):
        # Initialise pretrained net and final layers for cell classification
        super().__init__()
        self.convolutions = nn.Sequential(*(list(resnet.children())[0:-1]))
        self.dropout = nn.Dropout(self.DROPOUT_RATE)
        self.dense = nn.Linear(512, self.NUM_CLASSES)
        self.out = nn.Sigmoid()
        self.loss_fn = nn.BCELoss()
                
    def forward(self, image, target=None):
        batch_size = image.shape[0]
        
        # Extracts 512x1 feature vector from pretrained resnet18 conv layers
        x = self.convolutions(image).reshape(batch_size, -1)
        # Fully connected dense layer to 19 class output
        output = self.dense(self.dropout(x))
        # Sigmoid activations on output to infer class probabilities
        output_probs = self.out(output)
        
        if target is not None:
            loss = self.loss_fn(output_probs, target.to(torch.float32))  # why to float32???
            metrics = self.monitor_metrics(output_probs, target)
            return output_probs, loss, metrics
        return output_probs, None, None
    
    def fetch_optimizer(self):
        opt = torch.optim.Adam(self.parameters(), lr=3e-4)
        return opt
    
    def fetch_scheduler(self):
        sch = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
            self.optimizer, T_0=10, T_mult=1, eta_min=1e-6, last_epoch=-1
        )
        return sch

inf_aug = A.Compose([
    A.Normalize(
        mean=MEAN_CHANNEL_VALUES, 
        std=CHANNEL_STD_DEV, 
        max_pixel_value=1.0,
        p=1.0
    )
])

# %%
def infer(img, model, inf_aug):
    ''' In: np.array (512, 512, 3) image
        Out: np.array (1, 19) label-probs
    '''
    # Augment; re-shuffle channels; reshape; send to gpu
    X = inf_aug(image=img)['image']
    X = np.transpose(img, (2, 0, 1)).astype(np.float32)
    X = torch.tensor(X, dtype=torch.float32).to('cuda')
    X = X.unsqueeze(0)
    with torch.no_grad():
        out = model(X)[0]
    return out.cpu().detach().numpy()

# %% [markdown]
# ## Helper Functions

# %%
def get_inference(rgby_channel: tuple, model, inf_aug) -> tuple:
    """
    Input: rgby_channel for cell
    Pass: pass on model and augmentations for inference
    Output: prediction from inference of model
    
    NB: This function currently randomly predicts each class
    """
    # unpack rgby channel
    r, g, b, y = rgby_channel
    # stack img array
    img = np.dstack((r, g, b))
    # resize like in training
    img = resize(img, (512, 512))
    # get inference
    pred = infer(img, model, inf_aug)
    # ensure right shape
    assert pred.shape[0]==1
    assert pred.shape[1]==19
    return(pred[0])


def convert_sample_submission(path='/kaggle/input/hpa-single-cell-image-classification/sample_submission.csv')-> pd.core.frame.DataFrame:
    """
    Input: path to sample_submission.csv
    Output: csv submission without PredictionString
    """
    # read sample_submission csv
    submission = pd.read_csv(path)
    return(submission)


def get_files(path=path='/kaggle/input/hpa-single-cell-image-classification/test/'):
    """
    Input: path to file directory
    Output: pandas dataframe containing all IDs
    """
    files_red = glob.glob(path+'*_red.png')
    files_green = glob.glob(path+'*_green.png')
    # error test
    assert (len(files_red)==len(files_green)), "Different lengths of channels!"
    # create id dataframe
    id_s = [str(f.split('_red')[0].split('test/')[1]) for f in file_red]
    df = DataFrame(id_s, columns=['ID'])
    return(df)
    
    
def read_image_array(ID, path='/kaggle/input/hpa-single-cell-image-classification/test/'):
    """
    Input: ID and path to images
    Output: np arrays for each channels
    """
    # read path+ID
    r = imageio.imread(path+ID+'_red.png')
    g = imageio.imread(path+ID+'_green.png')
    b = imageio.imread(path+ID+'_blue.png')
    y = imageio.imread(path+ID+'_yellow.png')
    # segmentator takes in int16 not uint16
    r = np.array(r, dtype=np.int16)
    g = np.array(g, dtype=np.int16)
    b = np.array(b, dtype=np.int16)
    y = np.array(y, dtype=np.int16)
    # get width and height
    height_r, width_r = r.shape
    height_g, width_g = g.shape
    # check dimensions are the same
    assert ((height_r==height_g) and (width_r==width_g)), "Dimensions are not the same
    return r, g, b, y, width_r, height_r


def segment(ref_channels: List[str], segmentator: CellSegmentator)-> np.ndarray:
    """
    Input: reference channels for segementation class and segmentation class
    Output: mask for image
    """
    # Ref channels must be in order red, yellow, blue
    input_ = [[i] for i in ref_channels]  # Segmentator only accepts list of lists input
    nuc_segmentation = segmentator.pred_nuclei(input_[2])[0]
    cell_segmentation = segmentator.pred_cells(input_)[0]
    mask = label_cell(nuc_segmentation, cell_segmentation)[1]
    return mask


def get_rle_string(rgby_channel: tuple, binary_mask: np.ndarray, model, inf_aug)-> str:
    """
    Input: cell rgby channels and binary mask for cell
    Pass: pass on model and augmentations for inference
    Output: prediction string for cell
    """
    # get predictions
    class_preds = get_inference(rgby_channel, model, inf_aug)
    # add to prediction string
    enc = encode_binary_mask(binary_mask)
    # pred string
    pred_string = ''
    for jj, pred in enumerate(class_preds):
        pred_string += str(jj)+' '+str(pred)+' '+enc+ ' '
    return(pred_string)


def extract_and_predict(channels: tuple, mask: np.ndarray, model, inf_aug) -> str:
    """
    Input: whole image channels and mask for whole image
    Pass: passing on model and augmentations for inference
    Output: prediction string for whole image to be inputted to csv
    """
    # master predicted_string
    predicted_string = ''
    for label in np.unique(mask):
        # Get values from where image == label
        if label == 0:
            continue  # ignore background
        temp_mask = mask.copy()
        temp_mask[temp_mask != label] = 0
        temp_mask[temp_mask == label] = 1
        # Get temp mask bounding box coords
        idxs = np.asarray(temp_mask == 1).nonzero()
        y_min, y_max = idxs[0].min(), idxs[0].max()
        x_min, x_max = idxs[1].min(), idxs[1].max()

        # tuple of all channels to be classified
        rgby_channel_list = list()
        for channel in channels:
            # Zero pad and square off
            single_cell = temp_mask * channel
            single_cell = single_cell[y_min:(y_max + 1), x_min:(x_max + 1)]
            # append channel to list
            rgby_channel_list.append(single_cell)
        # return prediction string to append
        predicted_string += get_rle_string(tuple(rgby_channel_list), np.array(temp_mask, dtype=bool),
                                           model, inf_aug)
    return(predicted_string)


def encode_binary_mask(mask: np.ndarray)-> str:
    """
    Input: binary mask
    Output: encoded rle mask, decoded into ascii text
    """

    # check input mask --
    if mask.dtype != np.bool:
        raise ValueError(
           "encode_binary_mask expects a binary mask, received dtype == %s" %
           mask.dtype)

    mask = np.squeeze(mask)
    if len(mask.shape) != 2:
        raise ValueError(
           "encode_binary_mask expects a 2d mask, received shape == %s" %
           mask.shape)

    # convert input mask to expected COCO API input --
    mask_to_encode = mask.reshape(mask.shape[0], mask.shape[1], 1)
    mask_to_encode = mask_to_encode.astype(np.uint8)
    mask_to_encode = np.asfortranarray(mask_to_encode)

    # RLE encode mask --
    encoded_mask = coco_mask.encode(mask_to_encode)[0]["counts"]

    # compress and base64 encoding --
    binary_str = zlib.compress(encoded_mask, zlib.Z_BEST_COMPRESSION)
    base64_str = base64.b64encode(binary_str)
    return base64_str.decode()

# %% [markdown]
# # Inference

# %%
# load data
df = get_files()
# load pretrained model
resnet_model = resnet18(pretrained=False)
resnet_model.load_state_dict(torch.load(RESNET_PATH))
# define model class
model = ResNet18(resnet_model)
# load weights
model.load(MODEL_PATH)
# augmentations
inf_aug = A.Compose([
A.Normalize(
    mean=MEAN_CHANNEL_VALUES, 
    std=CHANNEL_STD_DEV, 
    max_pixel_value=1.0,
    p=1.0
    )
])

# %%
# Iterate over test dataframce
for image in df.itertuples():
    print('#####################################################')
    print('Segmenting image {}'.format(image.ID))  
    # segment and extract
    r, g, b, y, width, height = read_image_array(image.ID)
    # assign ref channels
    ref_channels = [r, y, b]
    # assign width and height
    df.at[image.Index, 'ImageWidth'] = width
    df.at[image.Index, 'ImageHeight'] = height
    # get mask
    mask = segment(ref_channels, segmentator)
    # get predicted string
    df.at[image.Index, 'PredictionString'] = extract_and_predict((r, g, b, y), 
                                                                 mask,
                                                                 model,
                                                                 inf_aug)
# Out:
# #####################################################
# Segmenting image 0040581b-f1f2-4fbe-b043-b6bfea5404bb
# #####################################################
# Segmenting image 004a270d-34a2-4d60-bbe4-365fca868193
# #####################################################
# Segmenting image 00537262-883c-4b37-a3a1-a4931b6faea5
# #####################################################
# Segmenting image 00c9a1c9-2f06-476f-8b0d-6d01032874a2
# #####################################################
# Segmenting image 0173029a-161d-40ef-af28-2342915b22fb
# #####################################################
# Segmenting image 01a14326-67b8-43b0-ac7a-ba6dfb3c38ad
# #####################################################
# Segmenting image 020a29cf-2c24-478b-8603-c22a90dc3e31
# #####################################################
# Segmenting image 02425037-3048-4ff3-9c0a-e9fc2d033e32
# #####################################################
# Segmenting image 02531b54-078d-4a33-9c9c-0632b58c0a9a
# #####################################################
# Segmenting image 025f04f1-6c68-4606-b34b-047738dd4804
# /opt/conda/lib/python3.7/site-packages/hpacellseg/utils.py:171: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   cell_label = remove_small_objects(cell_label, 344)
# /opt/conda/lib/python3.7/site-packages/hpacellseg/utils.py:178: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   nuclei_label = remove_small_objects(nuclei_label, 157)
# #####################################################
# Segmenting image 02861579-97fb-4482-a613-356e0bf5d090
# #####################################################
# Segmenting image 02b3c5aa-d70c-49d1-b3e5-3f5cc10375ca
# #####################################################
# Segmenting image 02f9ee97-bf2e-4d9d-bdfd-b903ec2e79c0
# #####################################################
# Segmenting image 036cd088-40fc-4ab0-a131-a6c02f02440a
# #####################################################
# Segmenting image 03aa8433-b927-4495-a6e2-d03cdc17d76b
# #####################################################
# Segmenting image 04c1b106-a5a4-419d-96c6-2750ebe2b50d
# #####################################################
# Segmenting image 05d2d9f7-2607-4c85-880d-31838d60f69c
# #####################################################
# Segmenting image 06dc4bba-d575-4a7d-bd3c-a855bae78b87
# #####################################################
# Segmenting image 077cd9bb-bec5-4577-aca4-97e5683619f6
# /opt/conda/lib/python3.7/site-packages/hpacellseg/utils.py:139: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   nuclei_label = remove_small_objects(nuclei_label, 157)
# #####################################################
# Segmenting image 08c34075-6bb9-4852-9f1d-511eeaf7d7ff
# #####################################################
# Segmenting image 08c4fe91-cc22-440e-8ee4-59724fd11e10
# #####################################################
# Segmenting image 097d3a61-15e2-413a-9ca8-fca2509f0854
# #####################################################
# Segmenting image 0a12663b-71ff-49e2-9fd9-b9a1bba5a9b4
# #####################################################
# Segmenting image 0a75821b-048f-4db2-a061-3c723008c3cf
# #####################################################
# Segmenting image 0bf0b707-99a4-4561-93fe-6c0ea0cfecf8
# #####################################################
# Segmenting image 0c0404a0-9eff-48d3-a853-fc7a076258e4
# #####################################################
# Segmenting image 0c2ea2b7-d0a0-4a14-9c70-e0428db1c298
# #####################################################
# Segmenting image 0c57f7f4-c9b9-4824-aa0e-c98bd8860434
# #####################################################
# Segmenting image 0c693c0d-1395-4d88-af7d-1368fe9f8437
# #####################################################
# Segmenting image 0cd887e1-bc16-4884-a453-4b210ada725c
# #####################################################
# Segmenting image 0cefc8d5-7ded-4de4-ba97-11b0b4a080b0
# #####################################################
# Segmenting image 0d775004-c453-4d03-bdc9-36661a64cbbd
# #####################################################
# Segmenting image 0e185461-0a8d-4b64-8d7d-a1dcec3b1412
# /opt/conda/lib/python3.7/site-packages/hpacellseg/utils.py:153: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   cell_label = remove_small_objects(cell_label, 344).astype(np.uint8)
# #####################################################
# Segmenting image 0e498bec-8155-4f31-9a23-8ebc5efe9dd7
# #####################################################
# Segmenting image 0e9eebd0-f151-4376-88ee-1721fbb49089
# #####################################################
# Segmenting image 0ea01e42-dee2-46d3-b189-930ff2ac9841
# #####################################################
# Segmenting image 0ec42e43-bb66-41a0-bd95-d143d10ca78a
# #####################################################
# Segmenting image 0eeb2555-a764-438e-bf11-916ef676dee7
# #####################################################
# Segmenting image 0f0b6d5d-642d-4d63-97ee-dcf4b2a9203e
# #####################################################
# Segmenting image 0f0e2a27-5a09-4965-8912-388d465eb994
# #####################################################
# Segmenting image 10dd5129-7e32-4272-9f1a-8bd052de2b9c
# #####################################################
# Segmenting image 10e2e7d0-7104-4f74-bb02-2c86e84f830c
# #####################################################
# Segmenting image 10fcd355-c389-4ccf-b42c-6767eb08d55a
# #####################################################
# Segmenting image 1102e583-1932-466e-a1b3-9fc333dceb80
# #####################################################
# Segmenting image 112b1c5d-b1a9-4815-8dab-3bfc01392018
# #####################################################
# Segmenting image 1131eb6f-11cc-4fe8-b327-628abd442210
# #####################################################
# Segmenting image 11c33f11-d41a-4a6b-b68e-12213a9e947d
# #####################################################
# Segmenting image 12667c6f-1d7e-44ca-9b75-ce8b6ddeaa0a
# #####################################################
# Segmenting image 12cb3a83-8a33-4bc3-9f7b-6bc096f616b4
# #####################################################
# Segmenting image 131ee8b4-de1d-435f-843c-a907dfda8416
# #####################################################
# Segmenting image 13f69d62-4d2d-4eb8-a9e2-9118328cc514
# #####################################################
# Segmenting image 13ffbbdc-0195-446b-8e21-d48efb8dd208
# #####################################################
# Segmenting image 1425e575-3e6e-4fc4-a7be-d446b543553b
# #####################################################
# Segmenting image 146f9220-88a3-4b46-b0db-5f4ba7563898
# #####################################################
# Segmenting image 15b2d2af-949f-4a6b-afdc-28182fd05212
# #####################################################
# Segmenting image 1642e4c4-7194-4565-bcd4-ff5a8b284d99
# #####################################################
# Segmenting image 182bc913-abca-46a9-b5fa-416ea862d655
# #####################################################
# Segmenting image 185897b6-bcb5-4f80-a3f0-a83824dbf912
# #####################################################
# Segmenting image 186208f7-d431-4673-b430-6a576538ea7e
# #####################################################
# Segmenting image 18b09c5d-7708-4bde-8d6f-85a69746f44c
# #####################################################
# Segmenting image 195dbedf-1af2-4f78-b162-c1c7ac2a30b6
# #####################################################
# Segmenting image 1a2a0cde-a1bc-4b71-81a1-459940468008
# #####################################################
# Segmenting image 1a5c9582-30a8-48de-b12a-3c012405624a
# #####################################################
# Segmenting image 1c13d9c9-f9f0-4845-beba-1743c59a2218
# #####################################################
# Segmenting image 1c5e2a57-20b6-4c2f-8787-e31ec078bcb2
# #####################################################
# Segmenting image 1db4aa8b-cab5-46a6-8530-8edd7653178b
# #####################################################
# Segmenting image 1de83a24-4043-4367-9cfc-735e5d5f40fd
# #####################################################
# Segmenting image 1e4a3df2-c137-437b-9eb3-d3ddc6d7beb6
# #####################################################
# Segmenting image 1ebc55df-43a6-4768-b813-d4be3e291a04
# #####################################################
# Segmenting image 1f4a5c57-54ee-4679-bbc0-cb1c668c3bf7
# #####################################################
# Segmenting image 2062d68b-4ab0-4f68-8dae-6bdc60b53f2f
# #####################################################
# Segmenting image 208759b0-de83-42aa-a2de-684dac541346
# #####################################################
# Segmenting image 20ffbb3e-0080-4e80-a626-054072b4c66a
# #####################################################
# Segmenting image 2108ef53-d3ae-4438-9dab-2cc5696a286b
# #####################################################
# Segmenting image 21d4426c-f36d-4f6e-b8de-e9c0085639b1
# #####################################################
# Segmenting image 22fa496b-f407-4df0-96ed-8942df0bcd9d
# #####################################################
# Segmenting image 253876a1-9d84-41ea-a64a-a90b6c59dbb2
# #####################################################
# Segmenting image 25d8f8c5-6d81-4dbc-a3a2-faa6babcb695
# #####################################################
# Segmenting image 261f25d9-27ec-4703-a855-9f92dae9ee6e
# #####################################################
# Segmenting image 26bf203c-9a58-4b07-acdb-29bc8f58de0f
# #####################################################
# Segmenting image 277b3f6d-099b-4b6d-8592-a06ad6f52beb
# #####################################################
# Segmenting image 283ecafc-ef2b-42f0-a6e1-88129a4fbdd7
# #####################################################
# Segmenting image 2849aa15-726b-4a14-867b-a3402cdf4328
# #####################################################
# Segmenting image 2990b07d-701b-430b-b00d-abe4e8beb60c
# #####################################################
# Segmenting image 29c3c936-145f-4bec-bcc7-9565cb48b819
# #####################################################
# Segmenting image 2a63fd5c-cd5f-4005-a085-e12a6ca38ab1
# #####################################################
# Segmenting image 2ab1f80e-2a07-4785-b7db-249a8c35d23e
# #####################################################
# Segmenting image 2b285126-df89-4954-b389-4206a64ac652
# #####################################################
# Segmenting image 2b58f7f8-e905-4af7-9ce0-ffc373416b5c
# #####################################################
# Segmenting image 2bb1ce03-ce95-4671-a6da-9153dca61b56
# #####################################################
# Segmenting image 2d312b7e-c49f-4d81-bd7f-7ab0db0e7cc8
# #####################################################
# Segmenting image 2d801991-e15a-488e-9729-ba5163a9be28
# #####################################################
# Segmenting image 2dd34a23-84bb-4849-a285-cb60fb40ac47
# #####################################################
# Segmenting image 2ea31aba-1f68-48cd-9691-cd4498669b3e
# #####################################################
# Segmenting image 2f33cde5-5a72-4818-9a23-d0300d5f99f6
# #####################################################
# Segmenting image 2f6838aa-37d6-41c9-a66a-d047330e0fbf
# #####################################################
# Segmenting image 3011d306-da16-43c5-9c7a-46953c4e5a32
# #####################################################
# Segmenting image 3093bc43-fab5-4138-baf8-7f641c062779
# #####################################################
# Segmenting image 30b9198b-7d1e-438e-8809-d6ce29082b0d
# #####################################################
# Segmenting image 31536bf6-4fed-4e43-bacc-b45d66f397ca
# #####################################################
# Segmenting image 31b45f24-8573-4717-9883-8bdafe822154
# #####################################################
# Segmenting image 31b7858e-c573-4dea-81c3-d9202d6430e6
# #####################################################
# Segmenting image 31c053f8-0682-4484-a0cc-c96888abe88a
# #####################################################
# Segmenting image 322bd30c-0aef-489e-a0f0-82a0253a3936
# #####################################################
# Segmenting image 332f8c9c-0c22-4312-942a-b71054eaec69
# #####################################################
# Segmenting image 334b4ba6-2618-4f88-8a26-cd2438e5e1a3
# #####################################################
# Segmenting image 33658e9c-d07d-46c5-b5ec-046338509a3e
# #####################################################
# Segmenting image 3382b344-abbb-4aaa-a09b-70788871fd09
# #####################################################
# Segmenting image 33932b91-1844-42f7-9363-90f72dae37a4
# #####################################################
# Segmenting image 33949d63-98cc-4967-b7a3-bf61423dad9b
# #####################################################
# Segmenting image 339d94e5-8241-4860-84cf-876ae68a3e15
# #####################################################
# Segmenting image 33bdf6a2-687f-4d49-b0cc-60f3fb87f7e4
# #####################################################
# Segmenting image 342fb1c0-5f4b-445d-817b-d4e44646342e
# #####################################################
# Segmenting image 345c63c8-cf07-4c86-b742-f4386de596d3
# #####################################################
# Segmenting image 35b4b43c-40f1-4abd-b17e-9923c50d8f91
# #####################################################
# Segmenting image 35b9fbab-b3cc-4b7f-bc4f-3798edae38ae
# #####################################################
# Segmenting image 3698ebac-6829-486b-bd77-99ff1fb7cb30
# #####################################################
# Segmenting image 37143960-74d6-4060-b853-6813616ca141
# #####################################################
# Segmenting image 373b19c9-4996-48c8-917a-ec53b69bca55
# #####################################################
# Segmenting image 37d203c0-450f-4637-aa24-a909880e9bd1
# #####################################################
# Segmenting image 3a124971-71e2-4d8f-bce9-06780d9b730c
# #####################################################
# Segmenting image 3aa2634c-fbb4-414a-b0e4-d756d8cbb9f7
# #####################################################
# Segmenting image 3b44694a-9be6-4b9f-9f5f-1dc6c95fff2e
# #####################################################
# Segmenting image 3ba07706-7f03-4e38-a763-1810c23d92af
# #####################################################
# Segmenting image 3bacbe9a-7c06-42c3-aabc-21a59c59c4d2
# #####################################################
# Segmenting image 3c61abe1-2d1c-482d-8545-5695d33dce46
# #####################################################
# Segmenting image 3c9a28bd-084f-4d23-9793-35fffa105652
# #####################################################
# Segmenting image 3cd4bd3e-3062-4501-bcf9-b9a200af9ab9
# #####################################################
# Segmenting image 3ec0dd97-bc18-4afa-b2dc-62f5df9ac9cd
# #####################################################
# Segmenting image 3efa7d8e-161b-48f1-8f18-013de3bc6cc0
# #####################################################
# Segmenting image 3ffb5912-8e8c-4857-ad8f-9871c31adf65
# #####################################################
# Segmenting image 405324ed-7135-48e1-88a7-ec2570d26709
# #####################################################
# Segmenting image 41d66623-0e0b-466e-bda4-3acd5ca3158f
# #####################################################
# Segmenting image 42875b07-663c-4722-b05a-c733d306b1d6
# #####################################################
# Segmenting image 43275475-ffca-4767-bb36-39299796a768
# #####################################################
# Segmenting image 434547ba-d0c8-4278-83ae-adb2b9e14e52
# #####################################################
# Segmenting image 434548f7-1d27-490f-8e0f-bdc89a6b0fbe
# #####################################################
# Segmenting image 435a6557-b524-486b-af1c-c5e0376b6862
# #####################################################
# Segmenting image 43b6580c-4e4e-4fad-8be2-9e577802028f
# #####################################################
# Segmenting image 43faf8ef-0fc7-46ea-931f-2215d17c1d6e
# #####################################################
# Segmenting image 442b3f44-e9ec-4610-9ad3-22ad014632e7
# #####################################################
# Segmenting image 44b010e7-fe05-4db2-a703-34e8bb9089a2
# #####################################################
# Segmenting image 44c5cdd8-82a3-453e-8d8c-166d69d2ae8d
# #####################################################
# Segmenting image 45a917c0-31c3-4ea6-9a08-03530dca7005
# #####################################################
# Segmenting image 46abc248-619b-4f6e-ae80-d55b5ef38e1e
# #####################################################
# Segmenting image 47d6d311-769c-4e43-b42c-bd856f566ae8
# #####################################################
# Segmenting image 4908687b-7f79-4f6a-bc03-bfbbad704442
# #####################################################
# Segmenting image 495caf15-faed-458d-962b-8c78d0bf7ea4
# #####################################################
# Segmenting image 49693c8f-7262-4de9-85c2-6f78fc4a4de3
# #####################################################
# Segmenting image 49b573a7-a887-499e-b96b-28fbe3fae7f7
# #####################################################
# Segmenting image 4a11d63d-4b10-4a67-acb6-c8e0621c6180
# #####################################################
# Segmenting image 4ac5412b-ef71-4186-b0f9-d71b738d343f
# #####################################################
# Segmenting image 4aee3c20-4f67-41c1-9f41-6a18ff3f09cc
# #####################################################
# Segmenting image 4b225a0e-c8b9-4e21-ab48-ea6d48b0b7b9
# #####################################################
# Segmenting image 4bd83958-ac57-4023-8372-452e80890763
# #####################################################
# Segmenting image 4d4b3d21-d24d-4508-802f-f72c13954b36
# #####################################################
# Segmenting image 4e276a12-11ef-4f62-bba3-5dfdd955e07e
# #####################################################
# Segmenting image 4e3a3478-422e-4b97-b7d1-07201a1ddd48
# #####################################################
# Segmenting image 4e3ae702-1b3c-4eff-b27d-bac809f39c3a
# #####################################################
# Segmenting image 4e576c52-1a26-4d05-912a-cbb70eee2cae
# #####################################################
# Segmenting image 4e81d557-fa1f-494e-b0d9-1df026e66098
# #####################################################
# Segmenting image 4e9084b6-ed40-4591-9f32-a91aa4679bf2
# #####################################################
# Segmenting image 4e9546e7-ffbb-4a44-b4a3-2efc05d6e970
# #####################################################
# Segmenting image 4ec55571-d282-4419-ab6d-ae0c9a0b65df
# #####################################################
# Segmenting image 4eccf6b9-63d9-4753-acee-f7666737d4a8
# #####################################################
# Segmenting image 4edc8b07-fbda-4bca-8275-b78c9197e898
# #####################################################
# Segmenting image 4ef031f4-ad85-40ab-b028-f5489a7359c6
# #####################################################
# Segmenting image 503c064a-05e2-441c-8153-816c26fef10a
# #####################################################
# Segmenting image 507f65bd-9af7-44ed-a431-ca3c254a3bd8
# #####################################################
# Segmenting image 5084ed0d-82b2-491a-9184-45749fbef076
# #####################################################
# Segmenting image 50dec4d4-a343-464a-a4ff-9f233301184b
# #####################################################
# Segmenting image 51314583-0db5-4398-91da-cfc2a3412d0b
# #####################################################
# Segmenting image 51f9bc45-17d3-44c9-b018-5b8d203afd17
# #####################################################
# Segmenting image 52173c83-0c3f-42ce-82de-a965f3a0d830
# #####################################################
# Segmenting image 5248c62f-218d-4c9b-84fa-fec3179d0a6f
# #####################################################
# Segmenting image 52bd6139-a06e-4c5b-9360-307ce651a476
# #####################################################
# Segmenting image 53024ee0-af61-46f3-a482-24a883dac72a
# #####################################################
# Segmenting image 532ca50d-85e6-4031-968d-022a6a5b1c84
# #####################################################
# Segmenting image 53476b9e-51be-40b1-8652-b1017a4793da
# #####################################################
# Segmenting image 54016809-dc74-461c-b98f-62b4c151c769
# #####################################################
# Segmenting image 558fee27-92a3-4ded-b67b-818a2cf19ff8
# #####################################################
# Segmenting image 56736ae6-f58f-40b5-a596-b799a4fe5153
# #####################################################
# Segmenting image 567e675f-f1b3-4ea6-80ec-00c85013ce89
# #####################################################
# Segmenting image 57010afb-88d9-4ef2-8d09-843ef32c6ed1
# #####################################################
# Segmenting image 57a03215-304e-4459-8f3c-bc777bd16c96
# #####################################################
# Segmenting image 57c2fcf7-3c81-4e60-a193-39e35be908f4
# #####################################################
# Segmenting image 57e7c6e6-4404-4ca9-8d6a-107b0fd68122
# #####################################################
# Segmenting image 58fb0147-6507-47cf-828b-b7dfba26f3d5
# #####################################################
# Segmenting image 59068890-d776-4561-98a4-74fb0ba40b9c
# #####################################################
# Segmenting image 590f9fc5-4fa3-4b53-9797-d40e91f45f38
# #####################################################
# Segmenting image 59636bb9-05fd-4d3e-ac4c-dd2ba7799dd0
# #####################################################
# Segmenting image 59652c48-0b9d-4cad-b569-3373c138818b
# #####################################################
# Segmenting image 598e782d-75b9-43bf-8697-77bf1c666188
# #####################################################
# Segmenting image 5af9bb81-719a-4374-9a12-5e5665329df6
# #####################################################
# Segmenting image 5b9706dc-d548-4026-862f-b9ca6fda7372
# #####################################################
# Segmenting image 5babfefe-9df9-42d5-b1ca-44128d97fc45
# #####################################################
# Segmenting image 5bae5ed1-56b3-4033-8eda-7fa269ba51f6
# #####################################################
# Segmenting image 5d7e25f7-4d52-4878-b873-1ec36549c71a
# #####################################################
# Segmenting image 5dcbd7b3-f54f-4a95-b693-6933960f9445
# #####################################################
# Segmenting image 5dda7aaf-98cc-40c8-b596-0fc2d4bad877
# #####################################################
# Segmenting image 5e26e332-d22a-4720-adca-1359835c031f
# #####################################################
# Segmenting image 5e536344-f67a-4667-8204-507ed93ff3f4
# #####################################################
# Segmenting image 5e719416-a904-43e6-9828-6d68fb1f1e3d
# #####################################################
# Segmenting image 5e7eacbe-6489-42ff-a953-7dbf6e3426bf
# #####################################################
# Segmenting image 5e817327-e3cf-4ecd-bad4-34e5dda21cdb
# #####################################################
# Segmenting image 5ee6f6d7-c56f-4e2e-8f1d-90cef1646a42
# #####################################################
# Segmenting image 5eedf48e-cee2-4df8-a934-c39a16f77255
# #####################################################
# Segmenting image 5f0a433e-f175-4ba7-9e42-7a77b21f4bb7
# #####################################################
# Segmenting image 5f4e4f65-b0b3-418f-8ddf-b7f63bdca09b
# #####################################################
# Segmenting image 5fa07ca5-de43-43ff-92a7-819904c8b63c
# #####################################################
# Segmenting image 607dfb58-9165-4f87-b9f6-76ae3db2aaf4
# #####################################################
# Segmenting image 62192c5e-9a7e-4b7e-ba92-b6b5220d2fd1
# #####################################################
# Segmenting image 6220622a-b7e6-47c7-bdfa-2dfe650771b2
# #####################################################
# Segmenting image 6367c9fd-073b-43c4-afe9-6dcd4ebba1da
# #####################################################
# Segmenting image 64d41f90-e46e-4122-90e3-42a4f2ac2937
# #####################################################
# Segmenting image 660a1029-2bc2-4dd3-8bb9-5b76fee7c832
# #####################################################
# Segmenting image 662d092f-ae4a-411a-9c4e-b1b9ce3f5196
# #####################################################
# Segmenting image 66382cfa-8da3-49e1-a57b-61ef7794f23f
# #####################################################
# Segmenting image 6652289f-2eab-450c-8c9b-5ef0d48329a1
# #####################################################
# Segmenting image 6699917c-e2f7-4b95-b130-356725d39346
# #####################################################
# Segmenting image 66bf7ad9-9520-4ce1-8d27-ba882f701bbd
# #####################################################
# Segmenting image 66db0c73-246b-4a21-bb77-ada5acf2692d
# #####################################################
# Segmenting image 66f72960-69fb-4c28-a58d-ca4a726b9985
# #####################################################
# Segmenting image 67066543-8e88-404f-a105-9ff5bdc359b7
# #####################################################
# Segmenting image 6770a219-1211-4807-a29d-d27a9e727add
# #####################################################
# Segmenting image 67ff4e10-fc8e-46bc-b323-9c550e630c8d
# #####################################################
# Segmenting image 690bd266-6160-4909-99d4-e64ca2e6980e
# #####################################################
# Segmenting image 69cf4292-34a0-47ef-9bd1-409402854289
# #####################################################
# Segmenting image 6b81c256-d2c3-48a6-936a-ad4f92dcd8bf
# #####################################################
# Segmenting image 6c3f08e3-e7d6-4cb8-8684-834a021cba03
# #####################################################
# Segmenting image 6cf4215f-e14b-4a33-8a2b-32ccd8c2e49a
# #####################################################
# Segmenting image 6e372919-71d3-4f29-ae63-b62a0d234fb8
# #####################################################
# Segmenting image 6e3d37c7-12e9-4389-8682-70c3e11dac03
# #####################################################
# Segmenting image 6ed41286-3b80-4c5f-bc81-2f394ebb1cdf
# #####################################################
# Segmenting image 6fb09267-c6ae-4472-896e-b922870ba7e0
# #####################################################
# Segmenting image 6fb43782-c679-44bc-9130-7e8ddb401711
# #####################################################
# Segmenting image 6fdc9830-b583-4195-8980-39a01215999a
# #####################################################
# Segmenting image 718bdfa2-537a-4e1a-bcda-d7ff37d9b5c1
# #####################################################
# Segmenting image 71b7eb37-d40b-493c-baf7-c63d9ac3c61e
# #####################################################
# Segmenting image 71dfd2f0-e1fc-4fc8-8c67-74244d1b9a62
# #####################################################
# Segmenting image 7220d1d6-8337-4311-ac67-e612af68c90c
# #####################################################
# Segmenting image 724c3309-9d9e-494c-8034-eb5d79f1ecbb
# #####################################################
# Segmenting image 7297c36b-920a-49e4-a901-a6ba55fc5947
# #####################################################
# Segmenting image 72ca5902-b93c-4174-b335-bf193b534956
# #####################################################
# Segmenting image 74ddbf26-f25c-459b-96ba-9541b5e935ee
# #####################################################
# Segmenting image 7577c1c0-2395-436f-837e-1df2d22d1240
# #####################################################
# Segmenting image 75bf5e12-29d3-4a69-bf49-c7fb7fff2996
# #####################################################
# Segmenting image 7636f1c4-d81b-467d-aeac-0f9d4048a655
# #####################################################
# Segmenting image 76537c66-3d65-4eb5-855f-dc80a7d7e880
# #####################################################
# Segmenting image 78c2dcc6-f7ed-4c89-aa2b-53dcf7b9e601
# #####################################################
# Segmenting image 791480d2-18ab-4077-b9a8-13e620a15b5c
# #####################################################
# Segmenting image 7aaf2b13-4502-4c2a-a16b-62a2ec11c853
# #####################################################
# Segmenting image 7b5e40b3-aa76-4e7c-a6c6-b1e5ebb8d807
# #####################################################
# Segmenting image 7c56dcfc-f5d3-4995-ab4a-0c05522533e0
# #####################################################
# Segmenting image 7ca5f161-cbe7-4c9c-90f6-0c51a7c260f4
# #####################################################
# Segmenting image 7cde5902-bab9-4245-b4b0-7cf04e1875be
# #####################################################
# Segmenting image 7d99d20b-454e-4c00-80e3-3860772cee46
# #####################################################
# Segmenting image 7ecb1354-6c90-4992-9476-a54b2ba2e2e9
# #####################################################
# Segmenting image 7efb8d74-d92e-4396-a6f7-d15bcca6f12a
# #####################################################
# Segmenting image 7f7e0904-5793-4741-920d-8b3697a14983
# #####################################################
# Segmenting image 7fa24a61-192c-4591-92c1-e9d7255c9554
# #####################################################
# Segmenting image 7fa8b220-ca07-47d4-addb-e9e0bd56fb29
# #####################################################
# Segmenting image 7fbf2271-6038-48b0-8750-b910a596affe
# #####################################################
# Segmenting image 7fde673a-7cbd-4edd-901a-ba47035a727f
# #####################################################
# Segmenting image 7fe7ab5e-728b-454e-9bcf-1ec2d9cece5b
# #####################################################
# Segmenting image 8071c29b-59e8-4c8a-a655-c60bc820deaa
# #####################################################
# Segmenting image 80a2d076-5d07-419c-aa6c-ae60d5644d1c
# #####################################################
# Segmenting image 80d3deaa-4f90-46be-a3bd-5b9561d6b165
# #####################################################
# Segmenting image 80fd429c-03d9-4c2c-ae7a-c24352509c25
# #####################################################
# Segmenting image 80fe02e0-0bd9-4a97-ada4-a87765d7fbd6
# #####################################################
# Segmenting image 8191f211-9fe0-4d8c-bf94-053522258353
# #####################################################
# Segmenting image 81edc9c5-a61a-4034-845f-974b51809bd4
# #####################################################
# Segmenting image 8220ce00-b9f4-48d4-8244-8802b6eab864
# #####################################################
# Segmenting image 82366267-3fd4-4214-9e46-e3789a591d80
# #####################################################
# Segmenting image 824cf8d8-1854-4e7b-b138-b7b56830350e
# #####################################################
# Segmenting image 8277eafd-f250-4abd-956b-c2b7d2b4065c
# #####################################################
# Segmenting image 828927e2-84f2-42bf-b62b-be90b7eacd6f
# #####################################################
# Segmenting image 82ba532c-b3da-4f53-bc64-32d50af5f5f2
# #####################################################
# Segmenting image 83805388-0144-4a28-b01c-0dc9b2a80d7e
# #####################################################
# Segmenting image 83b83c9e-324f-4f4d-8cc0-d384482ef36c
# #####################################################
# Segmenting image 83d15040-b478-4573-9e19-67f822151993
# #####################################################
# Segmenting image 84156bfd-d57d-4246-8501-a9b08d49aa85
# #####################################################
# Segmenting image 8471cdd3-d439-41f7-9400-61659237043b
# #####################################################
# Segmenting image 84895b21-d582-4fc8-b8a4-7ffcbab587a8
# #####################################################
# Segmenting image 84f8e59d-bb60-40ae-bb2a-37c3a7a844e0
# #####################################################
# Segmenting image 85222849-a8e8-4f6a-9fe7-22d997c76157
# #####################################################
# Segmenting image 85cc41c1-ebed-4fdc-b612-4f3acaea96f9
# #####################################################
# Segmenting image 878ca05e-65ac-4b7c-a2bc-acf338702619
# #####################################################
# Segmenting image 87ebd928-5646-41b6-ad78-b07319a5e110
# #####################################################
# Segmenting image 88ab1124-747c-4c29-bda4-166211c7109d
# #####################################################
# Segmenting image 88fcdbef-cac1-4990-adda-6c0935610aa2
# #####################################################
# Segmenting image 8959efcc-75e9-4cf3-b35d-d9fd7eab88cc
# #####################################################
# Segmenting image 89754d37-1d55-4e5a-9e33-bde4148c0c4b
# #####################################################
# Segmenting image 8a68d8d0-7a1f-4a1a-8da6-2da5834aad8a
# #####################################################
# Segmenting image 8aa0e43d-0815-4360-b45c-5f3d89b0b6d2
# #####################################################
# Segmenting image 8adb17b7-ce2c-4721-bf34-c1806c72b4d4
# #####################################################
# Segmenting image 8b01accc-0648-44ad-b12c-31f6d5a74073
# #####################################################
# Segmenting image 8b35b194-23d9-441b-8065-0920589d73c2
# #####################################################
# Segmenting image 8b6e2195-8658-4262-aa21-4bb769fe2b9f
# #####################################################
# Segmenting image 8bd69977-ac4f-4114-810d-d656f782da25
# #####################################################
# Segmenting image 8d477a7e-9352-41a6-b3e1-443b68706399
# #####################################################
# Segmenting image 8e91b61f-7b9e-4dc4-bfc7-c133bdb46c94
# #####################################################
# Segmenting image 8eebdf28-bd80-4fb3-bfc4-9343cb0f1f94
# #####################################################
# Segmenting image 8f30b9ab-87c4-4b9d-b009-ad39a94dcb4b
# #####################################################
# Segmenting image 8f753fd4-d0fe-489a-9a36-79efee45bf6b
# #####################################################
# Segmenting image 8fa4b738-b980-4f76-9ea1-1bb838e760f4
# #####################################################
# Segmenting image 8fd091d7-9538-414e-9dfd-a0879cbad644
# #####################################################
# Segmenting image 90113ead-65a2-4720-b671-d3a39189944c
# #####################################################
# Segmenting image 904a8ff0-87b1-4354-bb17-b09e928006b4
# #####################################################
# Segmenting image 909a6fb9-9825-4d3c-92ab-202fd75ef247
# #####################################################
# Segmenting image 918d8bc5-2ac9-449f-ac19-342c84225c34
# #####################################################
# Segmenting image 92cccd0a-8a4a-49bd-9b71-149ff15057b7
# #####################################################
# Segmenting image 92dc75bb-f70d-474b-9c05-8dd8444c8d1a
# #####################################################
# Segmenting image 92ec1107-d1f7-4dc3-8b83-642ec156b24d
# #####################################################
# Segmenting image 93bc5bb8-c24e-4fb1-afac-ed142f3d0f7a
# #####################################################
# Segmenting image 956becab-a340-42df-879e-630594d5ffcc
# #####################################################
# Segmenting image 95f9c9ec-72be-4bf1-9a4c-6794ffaacc20
# #####################################################
# Segmenting image 96050073-18cb-4dc6-bcd0-3081ac10c589
# #####################################################
# Segmenting image 97c9926c-b4c7-4c8d-aebd-12e72c94040c
# #####################################################
# Segmenting image 987a27d8-7726-45f7-91ad-7124f8a26ea0
# #####################################################
# Segmenting image 98d73145-885b-4d1c-97cf-17a8bc07a2e7
# #####################################################
# Segmenting image 98d86ce7-9ea6-4def-a161-cba52833cc76
# #####################################################
# Segmenting image 994b5f85-52a3-41ca-9efc-f06dff017678
# #####################################################
# Segmenting image 995a8045-d38a-491e-aa26-85c02ecaf81e
# #####################################################
# Segmenting image 9976bde1-36b0-496e-9037-fe0a1eb4861f
# #####################################################
# Segmenting image 99a6dd01-83ae-4057-b026-25e50767ad9f
# #####################################################
# Segmenting image 99c658eb-d1ca-4d5f-ac60-728948408473
# #####################################################
# Segmenting image 99e874e4-9d79-43b2-832c-dd890b4c8fd8
# #####################################################
# Segmenting image 9a10e2c4-e7ed-41c3-b710-8ca0066a984d
# #####################################################
# Segmenting image 9a39e0e1-a1b8-4313-a931-f30bfe246f39
# #####################################################
# Segmenting image 9af2791e-82c0-4ac0-a77f-17d8ad58989b
# #####################################################
# Segmenting image 9b1d4b27-6946-4b86-a818-8e91029c3dfa
# #####################################################
# Segmenting image 9b23b3e2-07d6-432c-92ab-3710f1b724d0
# #####################################################
# Segmenting image 9bbf402d-876e-4b4c-b308-0e48ddd1d199
# #####################################################
# Segmenting image 9d1dc997-ba2c-42a1-b06c-92ee3cba115f
# #####################################################
# Segmenting image 9dc9c2a3-eaab-47e4-a966-fe6b381e750e
# #####################################################
# Segmenting image 9ddb5cd9-08f6-4696-9ca2-22c14b34c5df
# #####################################################
# Segmenting image 9e08c0fb-3e42-438f-ab19-19e5c0a254e6
# #####################################################
# Segmenting image 9e75a6ad-3bcb-446e-a197-74df26f4de0d
# #####################################################
# Segmenting image 9eadf64a-af34-4192-ab12-478b90a57a95
# #####################################################
# Segmenting image 9ef19ed1-2502-4039-b13d-bd518df3b0b7
# #####################################################
# Segmenting image 9f3eb308-2dc2-469a-848a-5ae63e9d8f08
# #####################################################
# Segmenting image 9fc74831-2bc0-4ad2-b75a-d3bf1fcbce0a
# #####################################################
# Segmenting image a2ddb268-7546-47dc-bb97-487e57ab1003
# #####################################################
# Segmenting image a3352ae8-9bd7-49d7-9152-4ef30c6d73ee
# #####################################################
# Segmenting image a3b759f2-08ac-4871-baad-d2f2b4486310
# #####################################################
# Segmenting image a4508e8b-f8f7-49b4-9a29-535468b27dff
# #####################################################
# Segmenting image a4a6e1d3-4876-4991-b3e2-93dbe379c983
# #####################################################
# Segmenting image a4d32fd3-b974-4e15-afcd-82c7fadda7e9
# #####################################################
# Segmenting image a5299382-fb55-4a4a-aa4e-89789edf3d5c
# #####################################################
# Segmenting image a74f8346-39e8-4b4e-ad52-a998d52af16d
# #####################################################
# Segmenting image a755bfb5-00b4-4740-88f1-534b5a99fdff
# #####################################################
# Segmenting image a76c0f31-59f7-419a-ab1e-a0a5b8a855e1
# #####################################################
# Segmenting image a7bd9acf-269b-4dc9-8229-3f102bc6c43b
# #####################################################
# Segmenting image a86f33e1-1af8-457e-9df5-e54bcac5d7e8
# #####################################################
# Segmenting image a86f94d0-ccb0-478e-b4e3-1615b25de385
# #####################################################
# Segmenting image a8c26682-ca24-4c61-ba8a-bfd92e308f39
# #####################################################
# Segmenting image a951e8c5-8e1a-413e-b1be-bbd7d445a986
# #####################################################
# Segmenting image a98c8936-32a9-4aae-9ebf-9d95466f2856
# #####################################################
# Segmenting image aa0b1e1c-f014-4094-b3fa-d905705dcbd7
# #####################################################
# Segmenting image acb00930-f933-4ef7-b4ec-61225a8aba94
# #####################################################
# Segmenting image acb8abbe-f34a-43b5-8073-f11ead70b7cb
# #####################################################
# Segmenting image ae5710a8-9e14-4b9d-8535-2a2e1a05df9d
# #####################################################
# Segmenting image af3cb5c5-bd56-49c2-ac02-2a91178f5ac4
# #####################################################
# Segmenting image af650e14-9473-4691-b1aa-e1797607cd1f
# #####################################################
# Segmenting image af6c4ae3-4108-4168-b9a6-6dc8d0278d4a
# #####################################################
# Segmenting image af7d5a9f-285e-4dda-b4ed-92880fa45aa6
# #####################################################
# Segmenting image b0048f41-97b2-4f9e-b8d6-a69b2057a3b9
# #####################################################
# Segmenting image b066cdd1-09ad-45d3-863c-2980858a1c5e
# #####################################################
# Segmenting image b15e8cd0-9fb4-48e7-aa59-e7a370ef2a04
# #####################################################
# Segmenting image b162fe86-7438-4c08-978f-3bd48c737684
# #####################################################
# Segmenting image b1bf4996-3887-4f1b-8ec9-6783742dc4c5
# #####################################################
# Segmenting image b1f89a62-f22a-48c4-a1e0-892cb4f86b3c
# #####################################################
# Segmenting image b215f117-4700-41a1-af2d-6ad73a74385e
# #####################################################
# Segmenting image b2182310-502b-438c-b483-02526f7785ca
# #####################################################
# Segmenting image b2576a90-f01f-4300-9729-5ed381d45c95
# #####################################################
# Segmenting image b25d1448-86e0-4daa-b4e7-44d645825957
# #####################################################
# Segmenting image b32e04f5-0283-426f-b8ce-20ca1cef6407
# #####################################################
# Segmenting image b33829ee-b0c7-4e1c-b182-a4491f194638
# #####################################################
# Segmenting image b36e3727-6b72-4f1d-bc92-5110e2649f05
# #####################################################
# Segmenting image b3f97c88-5de4-48f5-a524-440010fcfc5e
# #####################################################
# Segmenting image b4298d76-5a7e-4d11-a087-dda2a22ceb74
# #####################################################
# Segmenting image b57ebf0b-fc7c-4691-b3e2-263e9d3f2e17
# #####################################################
# Segmenting image b6cc73bd-a46c-43f7-9bf9-24dd20d9f1f2
# #####################################################
# Segmenting image b6fac394-325f-4c94-9e9e-8d568f227089
# #####################################################
# Segmenting image b704a5e9-8948-43b3-a296-5364650ecd0b
# #####################################################
# Segmenting image b714a64f-5927-4e03-a262-f7bdf78d0585
# #####################################################
# Segmenting image b7ac1cda-3d94-4d11-90c8-44aec49c27d5
# #####################################################
# Segmenting image b7bbe19b-34bb-4297-a546-425fa9cbce0e
# #####################################################
# Segmenting image b8442d0e-5f44-4719-a056-16733cd4b0fb
# #####################################################
# Segmenting image b8a0356d-3f6d-4609-a972-a32be32aa513
# #####################################################
# Segmenting image b8b30645-3943-46f7-8205-7592e38b20d0
# #####################################################
# Segmenting image b8b5f134-bcd7-44ee-b181-70bc9bc7fc22
# #####################################################
# Segmenting image b8c47cef-9d2f-494c-b5e2-6bcafce77a6e
# #####################################################
# Segmenting image b8cd2025-6a58-40bb-8b5c-98d3c7abd0b8
# #####################################################
# Segmenting image b8d148fc-78d8-4755-a577-135f89cee895
# #####################################################
# Segmenting image b908f07e-ac25-4e27-b07b-5f9909df42a7
# #####################################################
# Segmenting image b95ba845-7a57-4cf2-9f89-171e04b44518
# #####################################################
# Segmenting image b97ad374-8f75-4d98-9696-08fb31760e41
# #####################################################
# Segmenting image b9d800e2-e8d3-42d6-a023-8ed2d9b3c00f
# #####################################################
# Segmenting image bbbf3ed2-5bc4-4e64-ad25-52e3c77808d7
# #####################################################
# Segmenting image bbecc719-f55f-4c78-ad74-737370a09678
# #####################################################
# Segmenting image bcd73d2f-4d30-48ac-b428-a50798313048
# #####################################################
# Segmenting image bcdcefda-67aa-4656-b152-a80bebd7d692
# #####################################################
# Segmenting image bd16688c-71f5-4d18-a06e-f707405a35b7
# #####################################################
# Segmenting image bd2b4e56-c333-461b-81b9-3ebed7402815
# #####################################################
# Segmenting image bd651304-74f9-4172-b753-281c22eeea51
# #####################################################
# Segmenting image bd661fb6-95bf-46fa-a884-fcc56c24e993
# #####################################################
# Segmenting image be61ed55-4575-4546-8f52-274776aa0203
# #####################################################
# Segmenting image bea8a86e-c5cd-4904-badd-c3b2857ce8d6
# #####################################################
# Segmenting image bf06239b-7eea-43a3-b984-40bf43645857
# #####################################################
# Segmenting image bfda20f1-0178-4a53-806b-babea0e95023
# #####################################################
# Segmenting image c0d7386b-07aa-433d-882c-8aff774dcdfb
# #####################################################
# Segmenting image c1013767-d0d6-42d0-be85-17e6de55e3ae
# #####################################################
# Segmenting image c11ebeea-fbf8-4e6c-9817-3615b5e7a97e
# #####################################################
# Segmenting image c1323b4f-a26c-416b-84f6-2d7e951c1ed3
# #####################################################
# Segmenting image c20fd2b4-7ac9-4d1c-8348-9228bc8be862
# #####################################################
# Segmenting image c212ddc9-29a7-40c3-ad66-97952378b0c6
# #####################################################
# Segmenting image c23ae8bf-a17b-49ee-aafb-efddf679c7fd
# #####################################################
# Segmenting image c277b921-e579-458b-b41b-1f1cf5b5023d
# #####################################################
# Segmenting image c2f10f94-1351-42d8-ba4d-428ac5f21211
# #####################################################
# Segmenting image c2f5f8a4-0137-4007-b1bf-64dc1b97be83
# #####################################################
# Segmenting image c45a0df5-80e4-47bd-833b-4fdb489022af
# #####################################################
# Segmenting image c4739d58-e56e-4b62-a8d9-a64bebdbc1c2
# #####################################################
# Segmenting image c5319b02-c0dd-4863-9980-9f0649394682
# #####################################################
# Segmenting image c54ebc44-62f3-4914-90de-467168a2d548
# #####################################################
# Segmenting image c5797c0a-62a1-43ff-8d38-1731c48ee2d0
# #####################################################
# Segmenting image c6379d83-6b05-4a29-8f56-05a381d94d2a
# #####################################################
# Segmenting image c63bfd23-a760-44dc-b6a6-2f40ac3b1855
# #####################################################
# Segmenting image c7276347-3e4a-49ee-928c-501325a6041b
# #####################################################
# Segmenting image c7360b95-bb35-452c-ad2c-2693aba7c38c
# #####################################################
# Segmenting image c7b32b2b-1323-4cce-92a7-3433ae81dfc8
# #####################################################
# Segmenting image c8504ed6-940e-440d-baff-d234d32488b7
# #####################################################
# Segmenting image c89b2a8b-c2fd-4bc1-abcc-6528706f6f8e
# #####################################################
# Segmenting image c92c74a3-bbd6-4623-b3f8-70951bae5e55
# #####################################################
# Segmenting image c9afced0-8222-41ba-9754-a2448b9109f1
# #####################################################
# Segmenting image ca01fc73-a926-4911-8d34-571a519a9fbb
# #####################################################
# Segmenting image ca0c64e9-880d-44b0-b373-1d4113cae189
# #####################################################
# Segmenting image cb484f82-5226-47f7-925a-7c0950d9b74f
# #####################################################
# Segmenting image cb72042a-47d1-404a-8b9f-f12b5680ab0d
# #####################################################
# Segmenting image cc10201a-659e-48b3-880f-2650009b187a
# #####################################################
# Segmenting image cc589ecb-47b4-46b0-af76-098c7e39dbb0
# #####################################################
# Segmenting image cc6f54e0-d9dc-4845-8142-8a92b0e079a8
# #####################################################
# Segmenting image cd65456d-cdf6-4f99-805d-bfb85c881b24
# #####################################################
# Segmenting image cda406d5-178a-4011-b4cc-389ded4dcf27
# #####################################################
# Segmenting image cde8ffb0-6765-46c7-839f-6cc4543beffb
# #####################################################
# Segmenting image ce8609b1-68b8-4455-b3d7-39b04e441db0
# #####################################################
# Segmenting image cee36bfb-c562-4ffc-9cd5-0e0cccf22786
# #####################################################
# Segmenting image cf36f604-e24e-403a-bac0-c9efe2c90e58
# #####################################################
# Segmenting image d1b45fa3-731f-4a74-94e2-60fec11dd4d8
# #####################################################
# Segmenting image d2460faf-ec28-4804-9a02-25455ae14d0e
# #####################################################
# Segmenting image d267f38c-6235-4c37-8f7a-030801204342

# %%
# submission cv
df.to_csv('/kaggle/working/submission.csv', index=False)
